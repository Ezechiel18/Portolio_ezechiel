# %% [markdown]
# **<h1> Restructuration et enrichissement du Système d'Information Géographique de Cérès Flore </h1>**

# %% [markdown]
# <i>Dans ce fichier je présenterai brièvement la démarche adoptée pour réorganiser le SIG de Cérès Flore et les outils mis en place pour garantir la performance de ce SIG dans le temps. Ceci en partant du diagnostic du SIG jusqu' aux analyses spatiales en passant par création du projet Qfield/Qfield Cloud.</i>
